# %%
import pandas as pd

# %%
df = pd.read_excel('source-data/26o-Centro-Sul-Americano-ILCA-6.xlsx')
df.head()
# Out:
#   Unnamed: 0 Unnamed: 1                FLOTILHA OURO Unnamed: 3  \
# 0       Col.       PAÍS                         NOME     Gênero
# 1          1        BRA  Erick Marcondes de M.Carpes          M
# 2          2        ARG                Lucia Falasca          F
# 3          3        BRA       Gabriella Marques Kidd          F
# 4          4        URU    Dolores Moreira Fraschini          F
#
#    CLASSIFICAÇÃO  Unnamed: 5 PONTUAÇÃO Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0  Classificação   Categoria      Nett      Total         Q1         Q2
# 1              1      Sub 19        15         24          1          1
# 2              1  Pré-Master        22         34          2          1
# 3              1      Sênior        33         52          3          4
# 4              2      Sênior        37         52          4          3
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0          Q3          Q4          Q5          F1          F2          F3
# 1           2           1           2           9           3           2
# 2           1           1          12           4           2           4
# 3           1           2           4          19           8           3
# 4           3          14           5           1           5          15
#
#   Unnamed: 16
# 0          F4
# 1           3
# 2           7
# 3           8
# 4           2

# %%
df.columns = df.iloc[0]
df = df.drop(0)
df = df.drop(['PAÍS', 'Gênero', 'Classificação', 'Categoria'], axis=1)
df.head()
# Out:
# 0 Col.                         NOME Nett Total Q1 Q2 Q3  Q4  Q5  F1 F2  F3 F4
# 1    1  Erick Marcondes de M.Carpes   15    24  1  1  2   1   2   9  3   2  3
# 2    2                Lucia Falasca   22    34  2  1  1   1  12   4  2   4  7
# 3    3       Gabriella Marques Kidd   33    52  3  4  1   2   4  19  8   3  8
# 4    4    Dolores Moreira Fraschini   37    52  4  3  3  14   5   1  5  15  2
# 5    5    Florencia Chiarella Salas   44    61  5  4  3  17   8   3  6   6  9

# %%
# rename columns
df = df.rename(columns=
                         {'Col.': 'Posição Geral', 'NOME': 'Nome Competidor', 'Total': 'Pontuação Total'})

# %%
df['Posição Geral'] = df.index

# %%
#turn all the Q1, Q2, ..., F3, F4 columns into rows
df = pd.melt(df, id_vars=['Posição Geral', 'Nome Competidor', 'Pontuação Total', 'Nett'], 
                  var_name='Flotilha', value_name='Pontuação Regata')

# %%
# rename flotilha
# from "Posição Geral" 1 to 37: "Flotilha" = "O"
# from "Posição Geral" 38 to 74: "Flotilha" = "P"

df['Flotilha'] = df['Posição Geral'].apply(lambda x: 'O' if x <= 37 else 'P')

# %%
# se o valor em 'Pontuação Regata' NÃO for um número, 'Punição' recebe o valor de 'Pontuação Regata' e 'Pontuação Regata' recebe ''
df['Punição'] = df['Pontuação Regata'].apply(lambda x: '' if isinstance(x, int) else x)
df['Pontuação Regata'] = df['Pontuação Regata'].apply(lambda x: '' if isinstance(x, str) else x)

# %%
df['Nome Competição'] = ['Central and South American Championship 2023'] * len(df)
df['ID Competição'] = [3] * len(df)
df['Classe Vela'] = ['Ilca 6'] * len(df)

